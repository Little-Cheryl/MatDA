# %%
import pandas as pd
from sklearn.cluster import KMeans
import numpy as np

# %%
import json
file_path = 'glass_target_clusters50.json'
n_clusters=50
df = pd.read_csv("glass_features.csv")

df
# Out:
#       Unnamed: 0      formula    gfa    composition  \
# 0              0           Al  False            Al1
# 1              1     Al(NiB)2   True     Al1 Ni2 B2
# 2              2  Al10Co21B19   True  Al10 Co21 B19
# 3              3  Al10Co23B17   True  Al10 Co23 B17
# 4              4  Al10Co27B13   True  Al10 Co27 B13
# ...          ...          ...    ...            ...
# 5675        5675        ZrTi9  False        Zr1 Ti9
# 5676        5676      ZrTiSi2   True    Zr1 Ti1 Si2
# 5677        5677      ZrTiSi3   True    Zr1 Ti1 Si3
# 5678        5678       ZrVCo8   True     Zr1 V1 Co8
# 5679        5679       ZrVNi2   True     Zr1 V1 Ni2
#
#       MagpieData minimum Number  MagpieData maximum Number  \
# 0                          13.0                       13.0
# 1                           5.0                       28.0
# 2                           5.0                       27.0
# 3                           5.0                       27.0
# 4                           5.0                       27.0
# ...                         ...                        ...
# 5675                       22.0                       40.0
# 5676                       14.0                       40.0
# 5677                       14.0                       40.0
# 5678                       23.0                       40.0
# 5679                       23.0                       40.0
#
#       MagpieData range Number  MagpieData mean Number  \
# 0                         0.0                   13.00
# 1                        23.0                   15.80
# 2                        22.0                   15.84
# 3                        22.0                   16.72
# 4                        22.0                   18.48
# ...                       ...                     ...
# 5675                     18.0                   23.80
# 5676                     26.0                   22.50
# 5677                     26.0                   20.80
# 5678                     17.0                   27.90
# 5679                     17.0                   29.75
#
#       MagpieData avg_dev Number  MagpieData mode Number  ...  \
# 0                        0.0000                    13.0  ...
# 1                        9.7600                     5.0  ...
# 2                        9.3744                    27.0  ...
# 3                        9.4576                    27.0  ...
# 4                        9.2016                    27.0  ...
# ...                         ...                     ...  ...
# 5675                     3.2400                    22.0  ...
# 5676                     8.7500                    14.0  ...
# 5677                     8.1600                    14.0  ...
# 5678                     2.4200                    27.0  ...
# 5679                     5.1250                    28.0  ...
#
#       MagpieData range GSmagmom  MagpieData mean GSmagmom  \
# 0                      0.000000                  0.000000
# 1                      0.595395                  0.238158
# 2                      1.548471                  0.650358
# 3                      1.548471                  0.712297
# 4                      1.548471                  0.836174
# ...                         ...                       ...
# 5675                   0.000023                  0.000020
# 5676                   0.000023                  0.000006
# 5677                   0.000023                  0.000005
# 5678                   1.548471                  1.238777
# 5679                   0.595395                  0.297697
#
#       MagpieData avg_dev GSmagmom  MagpieData mode GSmagmom  \
# 0                        0.000000                  0.000000
# 1                        0.285789                  0.000000
# 2                        0.754415                  1.548471
# 3                        0.769280                  1.548471
# 4                        0.769280                  1.548471
# ...                           ...                       ...
# 5675                     0.000004                  0.000023
# 5676                     0.000008                  0.000000
# 5677                     0.000007                  0.000000
# 5678                     0.495511                  1.548471
# 5679                     0.297697                  0.595395
#
#       MagpieData minimum SpaceGroupNumber  \
# 0                                   225.0
# 1                                   166.0
# 2                                   166.0
# 3                                   166.0
# 4                                   166.0
# ...                                   ...
# 5675                                194.0
# 5676                                194.0
# 5677                                194.0
# 5678                                194.0
# 5679                                194.0
#
#       MagpieData maximum SpaceGroupNumber  MagpieData range SpaceGroupNumber  \
# 0                                   225.0                                0.0
# 1                                   225.0                               59.0
# 2                                   225.0                               59.0
# 3                                   225.0                               59.0
# 4                                   225.0                               59.0
# ...                                   ...                                ...
# 5675                                194.0                                0.0
# 5676                                227.0                               33.0
# 5677                                227.0                               33.0
# 5678                                229.0                               35.0
# 5679                                229.0                               35.0
#
#       MagpieData mean SpaceGroupNumber  MagpieData avg_dev SpaceGroupNumber  \
# 0                               225.00                               0.0000
# 1                               201.40                              28.3200
# 2                               189.56                              17.9056
# 3                               190.68                              16.7824
# 4                               192.92                              13.9984
# ...                                ...                                  ...
# 5675                            194.00                               0.0000
# 5676                            210.50                              16.5000
# 5677                            213.80                              15.8400
# 5678                            197.50                               6.3000
# 5679                            218.25                              12.1250
#
#       MagpieData mode SpaceGroupNumber
# 0                                225.0
# 1                                166.0
# 2                                194.0
# 3                                194.0
# 4                                194.0
# ...                                ...
# 5675                             194.0
# 5676                             227.0
# 5677                             227.0
# 5678                             194.0
# 5679                             225.0
#
# [5680 rows x 136 columns]

# %%
y = df['gfa'].values
excluded = ["formula",
              "composition", "formula", "gfa"]

X = df.drop(excluded, axis=1)

# %%
kmeans = KMeans(n_clusters=n_clusters,max_iter=500,random_state=222)

# Fit the data to the KMeans model
kmeans.fit(X)

# Get the cluster labels
labels = kmeans.labels_

# Get the cluster centers
centers = kmeans.cluster_centers_

# Print the cluster labels and centers
print("Cluster Labels:", labels)
print("Cluster Centers:", centers)
# Out:
# /Users/jason/opt/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Cluster Labels: [11 19 19 ... 34 34 34]
# Cluster Centers: [[3.22766667e+03 1.55555556e+01 4.13703704e+01 ... 2.27983333e+02
#   1.38464074e+00 2.29000000e+02]
#  [2.45639286e+03 1.33750000e+01 5.82098214e+01 ... 2.12849125e+02
#   1.00464412e+01 2.11022321e+02]
#  [4.87267136e+03 1.46666667e+01 3.76431925e+01 ... 2.08811148e+02
#   1.10860647e+01 2.09342723e+02]
#  ...
#  [1.20345000e+03 2.21000000e+01 4.36000000e+01 ... 2.27463000e+02
#   2.40126000e+00 2.29000000e+02]
#  [3.42271429e+03 6.52380952e+00 4.20476190e+01 ... 2.07455238e+02
#   1.59564667e+01 1.96000000e+02]
#  [3.89057778e+03 1.62222222e+01 4.51111111e+01 ... 2.23153378e+02
#   2.80749458e+00 2.24244444e+02]]

# %%
cluster = {}
for i, x in enumerate(labels):
    if x in cluster:
        cluster[int(x)].append(i)
    else:
        cluster[int(x)] = [i]
for key in sorted(cluster):
    print(key, len(cluster[key]))
# Out:
# 0 27
# 1 224
# 2 213
# 3 245
# 4 149
# 5 121
# 6 184
# 7 125
# 8 126
# 9 107
# 10 230
# 11 107
# 12 97
# 13 202
# 14 146
# 15 95
# 16 77
# 17 88
# 18 110
# 19 108
# 20 84
# 21 39
# 22 87
# 23 117
# 24 125
# 25 118
# 26 264
# 27 96
# 28 71
# 29 19
# 30 189
# 31 91
# 32 321
# 33 92
# 34 276
# 35 26
# 36 118
# 37 25
# 38 60
# 39 61
# 40 76
# 41 79
# 42 61
# 43 55
# 44 84
# 45 9
# 46 170
# 47 20
# 48 21
# 49 45

# %%
# Save the dictionary to a file
with open(file_path, 'w') as file:
    json.dump(cluster, file)

# %%
for index in cluster[0]:
    print(df.iloc[index]["formula"])
# Out:
# Mo3Ru2
# Nb11Si4Mo5
# Nb11V5Si4
# Nb13Si4Mo3
# Nb13V3Si4
# Nb15Si2Ge3
# Nb15Si4Mo
# Nb15VSi4
# Nb17Si3
# Nb19(Si2Ge)2
# Nb19Si5Ge
# Nb20Si4Ge
# Nb39Si7Ge4
# Nb3Ni2
# Nb3SiMo
# Nb3VSi
# Nb40Si9Ge
# Nb4Si
# Nb5Si2Mo3
# Nb76.5Si8.5Ge15
# Nb77Si10Ge13
# Nb77Si23
# Nb7Si2Mo
# Nb7VSi2
# Nb80Si17Ge3
# Nb80Si19Ge
# Nb9Si4Mo7
