# %%
import json
import pandas as pd
import numpy as np
# from matminer.datasets import load_dataset
# from modnet.models import MODNetModel
# from modnet.preprocessing import MODData
import matplotlib.pyplot as plt 
from pymatgen.core import Composition
import json


file_path = 'bandgap_target_clusters50.json'
ncluster=50
featurefile = 'bandgap_features.csv'
property_column='gap expt'
with open(file_path, 'r') as file:
    cluster_ids = json.load(file)
    
df2 = pd.read_csv(featurefile)
y = df2['gap expt'].values
excluded = ["formula", "composition", "formula", "gap expt"]
X = df2.drop(excluded, axis=1)

for i, cluster_id in enumerate(range(0,ncluster)):
    target_id_list = cluster_ids[str(cluster_id)]

    Xt = X.iloc[target_id_list]
    yt = df2["gap expt"].iloc[target_id_list].values

    Xs = X.drop(target_id_list)
    ys = df2["gap expt"].drop(target_id_list).values
    break

# %%
Xt
# Out:
#       Unnamed: 0  MagpieData minimum Number  MagpieData maximum Number  \
# 4470        4470                       30.0                       52.0
# 4465        4465                       30.0                       80.0
# 4464        4464                       30.0                       80.0
# 4476        4476                       30.0                       80.0
# 4461        4461                       30.0                       80.0
# 4463        4463                       30.0                       80.0
# 4424        4424                       50.0                       70.0
# 4496        4496                       16.0                       30.0
# 4446        4446                       30.0                       80.0
# 4467        4467                       30.0                       34.0
# 4472        4472                       30.0                       34.0
#
#       MagpieData range Number  MagpieData mean Number  \
# 4470                     22.0               41.000000
# 4465                     50.0               42.500000
# 4464                     50.0               43.000000
# 4476                     50.0               43.500000
# 4461                     50.0               44.500000
# 4463                     50.0               46.000000
# 4424                     20.0               56.000000
# 4496                     14.0               22.615385
# 4446                     50.0               61.000000
# 4467                      4.0               32.000000
# 4472                      4.0               32.000000
#
#       MagpieData avg_dev Number  MagpieData mode Number  \
# 4470                  10.990000                    30.0
# 4465                  11.750000                    52.0
# 4464                  11.960000                    52.0
# 4476                  12.150000                    52.0
# 4461                  12.470000                    52.0
# 4463                  12.800000                    52.0
# 4424                   7.000000                    52.0
# 4496                   6.816568                    30.0
# 4446                  15.200000                    52.0
# 4467                   1.990000                    30.0
# 4472                   1.900000                    30.0
#
#       MagpieData minimum MendeleevNumber  MagpieData maximum MendeleevNumber  \
# 4470                                69.0                                90.0
# 4465                                69.0                                90.0
# 4464                                69.0                                90.0
# 4476                                69.0                                90.0
# 4461                                69.0                                90.0
# 4463                                69.0                                90.0
# 4424                                39.0                                90.0
# 4496                                69.0                                94.0
# 4446                                69.0                                90.0
# 4467                                69.0                                89.0
# 4472                                69.0                                89.0
#
#       MagpieData range MendeleevNumber  ...  MagpieData range GSmagmom  \
# 4470                              21.0  ...                        0.0
# 4465                              21.0  ...                        0.0
# 4464                              21.0  ...                        0.0
# 4476                              21.0  ...                        0.0
# 4461                              21.0  ...                        0.0
# 4463                              21.0  ...                        0.0
# 4424                              51.0  ...                        0.0
# 4496                              25.0  ...                        0.0
# 4446                              21.0  ...                        0.0
# 4467                              20.0  ...                        0.0
# 4472                              20.0  ...                        0.0
#
#       MagpieData mean GSmagmom  MagpieData avg_dev GSmagmom  \
# 4470                       0.0                          0.0
# 4465                       0.0                          0.0
# 4464                       0.0                          0.0
# 4476                       0.0                          0.0
# 4461                       0.0                          0.0
# 4463                       0.0                          0.0
# 4424                       0.0                          0.0
# 4496                       0.0                          0.0
# 4446                       0.0                          0.0
# 4467                       0.0                          0.0
# 4472                       0.0                          0.0
#
#       MagpieData mode GSmagmom  MagpieData minimum SpaceGroupNumber  \
# 4470                       0.0                                 64.0
# 4465                       0.0                                152.0
# 4464                       0.0                                152.0
# 4476                       0.0                                152.0
# 4461                       0.0                                152.0
# 4463                       0.0                                152.0
# 4424                       0.0                                141.0
# 4496                       0.0                                 64.0
# 4446                       0.0                                152.0
# 4467                       0.0                                 14.0
# 4472                       0.0                                 14.0
#
#       MagpieData maximum SpaceGroupNumber  MagpieData range SpaceGroupNumber  \
# 4470                                194.0                              130.0
# 4465                                194.0                               42.0
# 4464                                194.0                               42.0
# 4476                                194.0                               42.0
# 4461                                194.0                               42.0
# 4463                                194.0                               42.0
# 4424                                225.0                               84.0
# 4496                                194.0                              130.0
# 4446                                194.0                               42.0
# 4467                                194.0                              180.0
# 4472                                194.0                              180.0
#
#       MagpieData mean SpaceGroupNumber  MagpieData avg_dev SpaceGroupNumber  \
# 4470                        172.420000                            21.364200
# 4465                        172.160000                            20.529600
# 4464                        171.880000                            20.350400
# 4476                        171.600000                            20.160000
# 4461                        171.040000                            19.745600
# 4463                        170.200000                            19.040000
# 4424                        167.500000                            28.750000
# 4496                        126.307692                            62.485207
# 4446                        161.800000                             9.800000
# 4467                        104.110000                            89.610000
# 4472                        105.100000                            86.100000
#
#       MagpieData mode SpaceGroupNumber
# 4470                             152.0
# 4465                             152.0
# 4464                             152.0
# 4476                             152.0
# 4461                             152.0
# 4463                             152.0
# 4424                             152.0
# 4496                             194.0
# 4446                             152.0
# 4467                              14.0
# 4472                              14.0
#
# [11 rows x 133 columns]

# %%
Xt[8:]
# Out:
#       Unnamed: 0  MagpieData minimum Number  MagpieData maximum Number  \
# 4446        4446                       30.0                       80.0
# 4467        4467                       30.0                       34.0
# 4472        4472                       30.0                       34.0
#
#       MagpieData range Number  MagpieData mean Number  \
# 4446                     50.0                    61.0
# 4467                      4.0                    32.0
# 4472                      4.0                    32.0
#
#       MagpieData avg_dev Number  MagpieData mode Number  \
# 4446                      15.20                    52.0
# 4467                       1.99                    30.0
# 4472                       1.90                    30.0
#
#       MagpieData minimum MendeleevNumber  MagpieData maximum MendeleevNumber  \
# 4446                                69.0                                90.0
# 4467                                69.0                                89.0
# 4472                                69.0                                89.0
#
#       MagpieData range MendeleevNumber  ...  MagpieData range GSmagmom  \
# 4446                              21.0  ...                        0.0
# 4467                              20.0  ...                        0.0
# 4472                              20.0  ...                        0.0
#
#       MagpieData mean GSmagmom  MagpieData avg_dev GSmagmom  \
# 4446                       0.0                          0.0
# 4467                       0.0                          0.0
# 4472                       0.0                          0.0
#
#       MagpieData mode GSmagmom  MagpieData minimum SpaceGroupNumber  \
# 4446                       0.0                                152.0
# 4467                       0.0                                 14.0
# 4472                       0.0                                 14.0
#
#       MagpieData maximum SpaceGroupNumber  MagpieData range SpaceGroupNumber  \
# 4446                                194.0                               42.0
# 4467                                194.0                              180.0
# 4472                                194.0                              180.0
#
#       MagpieData mean SpaceGroupNumber  MagpieData avg_dev SpaceGroupNumber  \
# 4446                            161.80                                 9.80
# 4467                            104.11                                89.61
# 4472                            105.10                                86.10
#
#       MagpieData mode SpaceGroupNumber
# 4446                             152.0
# 4467                              14.0
# 4472                              14.0
#
# [3 rows x 133 columns]

# %%
from sklearn.metrics import balanced_accuracy_score
y_true = [1,1]
y_pred = [0,0]
balanced_accuracy_score(y_true, y_pred)
# Out:
# /home/rongzhid/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:2006: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# 0.0
